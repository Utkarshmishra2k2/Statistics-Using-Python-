# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarshmishra2k2/Statistics-Using-Python-/blob/main/Statistics_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Statistical Distribution **

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Binomial Distribution

# %%
from scipy.stats import binom

# %%
x=np.arange(0,50)             
n=50                          
p=0.1                          

Dist=binom(n,p)              
fig=plt.gcf();                                                                  
fig.set_size_inches(40,12)                                                     
sns.barplot(x=x,y=Dist.pmf(x));

# %%
x=np.arange(0,50)           
n=50                          
p=0.1                         

Dist=binom(n,p)                
fig=plt.gcf();                               
fig.set_size_inches(40,12)                    
sns.barplot(x=x,y=Dist.cdf(x));

# %%
x=np.arange(0,25)            
n=25                         
p=0.9                         
Dist=binom(n,p)              
fig=plt.gcf();                         
fig.set_size_inches(40,12)              
sns.barplot(x=x,y=Dist.pmf(x));

# %%
x=np.arange(0,25)    
n=25                       
p=0.9                  

Dist=binom(n,p)          
fig=plt.gcf();                    
fig.set_size_inches(40,12)        
sns.barplot(x=x,y=Dist.cdf(x));

# %% [markdown]
# Geometric Distribution

# %%
from scipy.stats import geom

# %%
x=np.arange(0,25)         
p=0.1                       

Dist=geom(p)             
fig=plt.gcf();                
fig.set_size_inches(40,12)         
sns.barplot(x=x,y=Dist.pmf(x));

# %%
x=np.arange(0,25)      
p=0.3                  

Dist=geom(p)             
fig=plt.gcf();                
fig.set_size_inches(40,12)       
sns.barplot(x=x,y=Dist.cdf(x));

# %%
#Here I Importing The Library 
import numpy as np
from math import sqrt
from scipy.stats import norm

# %% [markdown]
# **Z-Test (For Known Variance)**

# %% [markdown]
# Two Tailed

# %%
#Here I Created The Data Base
ChipsWeight=[51515,1541,114515,51145145,5156465,841,4512145,45215,415245,4121,7851,78,4551,65515]
BallBearingRadius=[5415,452115,4521,5405,52145,451205,54154,7854778,784252,745,7415654,784154,5465,5421,5124574,3216544,52165,541587,4159848]
UserRating=[5,4,1,7,8,6,2,5,8,6,8,2,4,5,6,4,7,7,5,4,7,8,3,5,9,]
Mileage=[40.41,50,65.65,45.245,455.55,784.5245,4851.45,66521.521,451.541,4515.465,65457.5645,]

# %%
mu=5             #Here I Enter Mu value 
Sigma=0.2             #Here Enter Sigma value 
Alpha=0.05             #Here Enter Alpha value
Sample=Mileage                         #Here I Taken Mileage As Sample
n=len(Mileage)                    #Here I Taken The Length Of Sample
Mean =np.mean(Sample)                  #Here I Calculated The Sample Mean
z=(Mean-mu)/(Sigma/sqrt(n))            #Here I calculated The Test Statistics
zcritical=norm.ppf(1-Alpha/2)
pvalue=2*(1.0-norm.cdf(np.abs(z)))
pvalue = float ("{:4f}".format(pvalue))
if (np.abs(z)> norm.ppf(1-Alpha/2)):
    print("Reject Null Hypothesis: p-value =",pvalue,"And Alpha =",Alpha)
else:
    print("Not Enough EvidenceTo Reject Null Hypothesis: p-value =",pvalue,"And Alpha =",Alpha)
# Out:
# Reject Null Hypothesis: p-value = 0.0 And Alpha = 0.05
